# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd



import pandas.io.data as web
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
serdate='2015-1-1'
sdate='2015-01-02'
l=['^VIX', 'SPLK', 'SPY', 'DATA','TSLA']
for i in l:
    DT = web.DataReader(name=i, data_source='yahoo',
                     start=serdate)


    DT['CloseN'] = DT['Close']/DT['Close'][sdate]

    DT['CloseN'].plot(figsize=(8, 5), grid=True)

# %%
SPY = web.DataReader(name='SPY', data_source='yahoo',
                     start=serdate)

# %%
SPY.head()
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2015-01-02  206.380005  206.880005  204.179993  205.429993  121465900
# 2015-01-05  204.169998  204.369995  201.350006  201.720001  169632600
# 2015-01-06  202.089996  202.720001  198.860001  199.820007  209151400
# 2015-01-07  201.419998  202.720001  200.880005  202.309998  125346700
# 2015-01-08  204.009995  206.160004  203.990005  205.899994  147217800
#
#              Adj Close
# Date
# 2015-01-02  202.474445
# 2015-01-05  198.817829
# 2015-01-06  196.945171
# 2015-01-07  199.399337
# 2015-01-08  202.937684

# %%
import superimp

# %%
superimp.superImpose()
